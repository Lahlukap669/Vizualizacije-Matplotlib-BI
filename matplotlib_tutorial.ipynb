# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1, 2, 3, 4])
plt.show()

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %%
#first method
fig = plt.figure() #creates figure
ax = fig.add_subplot()
plt.show()

# %%
#second method
fig= plt.figure() #creates figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
#third method (recommended)
fig, ax = plt.subplots()
ax.plot(x, y);

# %% [markdown]
# # Matplotlib example workflow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

#setup plot
fig, ax = plt.subplots(figsize=(10, 10)) #width, height

#plot the data
ax.plot(x, y)

#costumize plot
ax.set(title="Simple plot", xlabel="x-axis", ylabel="y-axis")

#save and show
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## Making figures with numpy arrays

# %%
#create some data
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#plot the data
fig, ax = plt.subplots()
ax.plot(x, x**2)

# %%
#use the same data to make scatter
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
#Another scatter
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
#Make a plot from dictionary

nut_butter_prices = {"Almond butter":10, "Penaut butter":8, "Cashew butter":12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Butter Prices", ylabel="Price [€]")
# Out:
# [Text(0.5, 1.0, 'Butter Prices'), Text(0, 0.5, 'Price [€]')]

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
#Make some data
x = np.random.randn(1000) #ustvari normalno porazdelitev
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([ 12.,  38.,  91., 184., 206., 200., 138.,  95.,  27.,   9.]),
#  array([-2.90823865, -2.32592685, -1.74361505, -1.16130325, -0.57899144,
#          0.00332036,  0.58563216,  1.16794396,  1.75025576,  2.33256756,
#          2.91487936]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## two options for subplots

# %%
#Option 1

fig, ((ax1, ax2), (ax3, ax4))  = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

#plot to different axies
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([  6.,  30.,  70., 174., 196., 233., 187.,  59.,  39.,   6.]),
#  array([-3.12814171, -2.51558978, -1.90303785, -1.29048591, -0.67793398,
#         -0.06538204,  0.54716989,  1.15972183,  1.77227376,  2.38482569,
#          2.99737763]),
#  <BarContainer object of 10 artists>)

# %%
#Option 2 - list index way

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas dataframes

# %%
import pandas as pd

# %%
#Make a dataframe
car_sales = pd.read_csv("car-sales.csv")

ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2024", periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('$\.\,', '')
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales["Price"][0]
# Out:
# '$4,000.'

# %%
car_sales["Sale date"] = pd.date_range("1/1/2024", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sale date
# 0  Toyota  White         150043      4   $4,000. 2024-01-01
# 1   Honda    Red          87899      4   $5,000. 2024-01-02
# 2  Toyota   Blue          32549      3   $7,000. 2024-01-03
# 3     BMW  Black          11179      5  $22,000. 2024-01-04
# 4  Nissan  White         213095      4   $3,500. 2024-01-05
# 5  Toyota  Green          99213      4   $4,500. 2024-01-06
# 6   Honda   Blue          45698      4   $7,500. 2024-01-07
# 7   Honda   Blue          54738      4   $7,000. 2024-01-08
# 8  Toyota  White          60000      4   $6,250. 2024-01-09
# 9  Nissan  White          31600      4   $9,700. 2024-01-10

# %%
#car_sales['Price'] = car_sales['Price'].fillna(0).astype(int)
#car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
#car_sales

# %%
#lets plot the total sales
#car_sales.plot(x="Sale date", y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
#How about bar graph?
x = np.random.rand(10, 4)
x

#turn it into dataframe
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.670596  0.598958  0.775223  0.639514
# 1  0.836743  0.172291  0.487006  0.828490
# 2  0.651826  0.171889  0.843306  0.104338
# 3  0.389357  0.373395  0.139942  0.019563
# 4  0.433346  0.499360  0.717542  0.411299
# 5  0.129176  0.260564  0.070344  0.726414
# 6  0.781970  0.789306  0.864008  0.199588
# 7  0.195024  0.356168  0.678819  0.512610
# 8  0.581644  0.617867  0.517641  0.405217
# 9  0.804881  0.511402  0.020670  0.566097

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
#How about histograms?

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
#Lets try another dataset
hd = pd.read_csv("heart-disease.csv")

# %%
hd["age"].plot.hist(bins=10);

# %%
hd.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
hd.plot.hist(figsize=(10, 30), subplots=True);

# %% [markdown]
# ### Which one should you use pyplot vs matplotlib OO method
#
# * When plotting something quickly, okay to use the pyplot method
# * When plotting something more advanced, use the OO method

# %%
over50 = hd[hd["age"]>50]

# %%
len(over50)
# Out:
# 208

# %%
over50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
## Pyplot method
over50.plot(kind="scatter", x="age", y="chol", c="target");

# %%
## OO Method
fix, ax = plt.subplots(figsize=(10, 6))
over50.plot(kind="scatter", x="age", y="chol", c="target", ax=ax);

#ax.set_xlim([45, 100]);

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize=(10, 7))

#plot the data
scatter = ax.scatter(x=over50["age"], 
                     y=over50["chol"], 
                     c=over50["target"]);
#Customize
ax.set(title="Heart disease and cholesterol", xlabel="Age", ylabel="Cholesterol");

#Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

#add a horizontal line
ax.axhline(over50["chol"].mean(), linestyle="--");

# %%
# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10, 10), sharex=True);

##add data
scatter = ax0.scatter(x=over50["age"],
                     y=over50["chol"],
                     c=over50["target"])

#Customize ax0
ax0.set(title="Heart Disease and cholesterol levels",
       ylabel="Cholesterol")

#add legend
ax0.legend(*scatter.legend_elements(), title="Target")

#add meanline
ax0.axhline(y=over50["chol"].mean(),
            linestyle="--");

##add data
scatter = ax1.scatter(x=over50["age"],
                     y=over50["thalach"],
                     c=over50["target"])

#Customize ax0
ax1.set(title="Heart Disease and max HR levels",
       xlabel="Age",
       ylabel="Max heart rate")

#add legend
ax1.legend(*scatter.legend_elements(), title="Target")

#add meanline
ax1.axhline(y=over50["thalach"].mean(),
            linestyle="--");

#add a title to a figure
fig.suptitle("Heart disease analysis", fontsize=20, fontweight="bold");

# %% [markdown]
# ## Customizing matplotlib plots and getting stylish

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Use the style
#plt.style.use("seaborn-whitegrid")

# %%
#Create some dummy data
x = np.random.randn(10, 4)
x
# Out:
# array([[-0.65160263, -1.33074964,  0.38318843, -1.56974195],
#        [-0.94067519,  0.61594148, -0.95855078,  0.74804523],
#        [-1.07202549,  0.22592015,  1.50819331,  1.35531317],
#        [-2.17897713,  1.16855962, -0.07986395,  0.78772555],
#        [ 0.81208417,  0.25408935,  0.02553968,  0.54138087],
#        [-0.27553359,  1.48834386, -0.76084688, -0.21732229],
#        [-0.10391543,  0.38665829, -0.948499  ,  1.91804834],
#        [ 0.54175089, -0.60319962, -1.9228775 , -2.13446566],
#        [ 0.26286576, -0.48747539, -2.02877326,  0.92085989],
#        [-0.29732782,  0.216741  , -0.11709503,  0.15008165]])

# %%
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0 -0.651603 -1.330750  0.383188 -1.569742
# 1 -0.940675  0.615941 -0.958551  0.748045
# 2 -1.072025  0.225920  1.508193  1.355313
# 3 -2.178977  1.168560 -0.079864  0.787726
# 4  0.812084  0.254089  0.025540  0.541381
# 5 -0.275534  1.488344 -0.760847 -0.217322
# 6 -0.103915  0.386658 -0.948499  1.918048
# 7  0.541751 -0.603200 -1.922877 -2.134466
# 8  0.262866 -0.487475 -2.028773  0.920860
# 9 -0.297328  0.216741 -0.117095  0.150082

# %%
ax = df.plot(kind="bar");

# %%
#Customize plot with set method
plt.style.use("tableau-colorblind10")
ax = df.plot(kind="bar")
ax.set(title="random graph from random numbers", 
      xlabel="Row number",
      ylabel="Random number")
ax.legend().set_visible(True);

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize=(10, 7))

#plot the data
scatter = ax.scatter(x=over50["age"], 
                     y=over50["chol"], 
                     c=over50["target"],
                    cmap="winter");
#Customize
ax.set(title="Heart disease and cholesterol", xlabel="Age", ylabel="Cholesterol");

#Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

#add a horizontal line
ax.axhline(over50["chol"].mean(), linestyle="--", color="red");

# %%
# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10, 10), sharex=True);

##add data
scatter = ax0.scatter(x=over50["age"],
                     y=over50["chol"],
                     c=over50["target"],
                     cmap="winter")

#Customize ax0
ax0.set(title="Heart Disease and cholesterol levels",
       ylabel="Cholesterol")

ax0.set_xlim([50, 80])
#add legend
ax0.legend(*scatter.legend_elements(), title="Target")

#add meanline
ax0.axhline(y=over50["chol"].mean(),
            linestyle="--", color="red");

##add data
scatter = ax1.scatter(x=over50["age"],
                     y=over50["thalach"],
                     c=over50["target"],
                     cmap="winter")

#Customize ax0
ax1.set(title="Heart Disease and max HR levels",
       xlabel="Age",
       ylabel="Max heart rate")

ax1.set_xlim([50, 80])
ax1.set_ylim([60, 200])
#add legend
ax1.legend(*scatter.legend_elements(), title="Target")

#add meanline
ax1.axhline(y=over50["thalach"].mean(),
            linestyle="--", color="red");

#add a title to a figure
fig.suptitle("Heart disease analysis", fontsize=20, fontweight="bold");

# %%
fig.savefig("images/heart-disease-analysis.png")
